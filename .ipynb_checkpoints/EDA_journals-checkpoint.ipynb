# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("telemedicine-journal-publications.csv")
df.head()
# Out:
#                                       AU  \
# 0                             VARSHNEY U
# 1  SURANA S;PATRA R;NEDEVSCHI S;BREWER E
# 2                               HAZEN ME
# 3                    SHARKEY N;SHARKEY A
# 4                              BARRETT D
#
#                                                   DE  \
# 0                                                NaN
# 1  INFORMATION AND COMMUNICATION TECHNOLOGIES;  T...
# 2  BIOTELEMETRIC DATA;  BODY NETWORK SENSORS;  HE...
# 3  COMPUTER SCIENCE AND MEDICINE;  DA VINCI SURGI...
# 4  LONG-TERM CONDITIONS;  REMOTE MONITORING;  TEL...
#
#                                                   ID  \
# 0  MOBILE DEVICES;  MOBILE TELEMEDICINE; DATA PRO...
# 1                                                NaN
# 2                                                NaN
# 3  ETHICS;  ROBODOC;  ROBOTIC SURGERY;  SURGICAL ...
# 4  AGED;  AMBULATORY MONITORING;  ARTICLE;  CHRON...
#
#                                                   C1  \
# 0  DEPT. OF COMP. INFORMATION SYSTEMS, GEORGIA ST...
# 1  ELECTRICAL ENGINEERING AND COMPUTER SCIENCES (...
# 2                                           INTELLON
# 3  DEPARTMENTO OF AI AND ROBOTICS, UNIVERSITY OF ...
# 4  FACULTY OF HEALTH AND SOCIAL CARE, UNIVERSITY ...
#
#                                                   CR                  JI  \
# 0                                                NaN            COMPUTER
# 1  BREWER, E., THE CASE FOR TECHNOLOGY IN DEVELOP...            COMPUTER
# 2                                                NaN            COMPUTER
# 3  GARCIA, P., TRAUMA POD: A SEMI-AUTOMATED TELER...            COMPUTER
# 4  ABRAHAM, W., ADAMSON, P., BOURGE, R., WIRELESS...  NURS. OLDER PEOPLE
#
#                                                   AB         AR  coden  \
# 0  THE USE OF THE WIRELESS COMMUNICATION TECHNOLO...        NaN  CPTRB
# 1  A NOVEL ICT PROJECT IN RURAL INDIA USES LONG-D...        NaN  CPTRB
# 2  SERVICE PROVIDERS CAN USE POWERLINE COMMUNICAT...        NaN  CPTRB
# 3  ROBOTIC SURGERY IS A RELATIVELY NEW TECHNOLOGY...  6374197.0  CPTRB
# 4  LONG-TERM CONDITIONS HAVE A NEGATIVE EFFECT ON...        NaN    NaN
#
#                                                   RP  ...      DB  \
# 0  VARSHNEY, U.; DEPT. OF COMP. INFORMATION SYSTE...  ...  SCOPUS
# 1  SURANA, S.; ELECTRICAL ENGINEERING AND COMPUTE...  ...  SCOPUS
# 2  HAZEN, M.E.; INTELLONEMAIL: MARK.HAZEN@INTELLO...  ...  SCOPUS
# 3  SHARKEY, N.; DEPARTMENTO OF AI AND ROBOTICS, U...  ...  SCOPUS
# 4  BARRETT, D.; FACULTY OF HEALTH AND SOCIAL CARE...  ...  SCOPUS
#
#                                                   TI  \
# 0                               PERVASIVE HEALTHCARE
# 1  DEPLOYING A RURAL WIRELESS TELEMEDICINE SYSTEM...
# 2  THE TECHNOLOGY BEHIND HOMEPLUG AV POWERLINE CO...
# 3     ROBOTIC SURGERY: ON THE CUTTING EDGE OF ETHICS
# 4  THE ROLE OF TELEMONITORING IN CARING FOR OLDER...
#
#                                                  url    VL    PY  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...  36.0  2003
# 1  https://www.scopus.com/inward/record.uri?eid=2...  41.0  2008
# 2  https://www.scopus.com/inward/record.uri?eid=2...  41.0  2008
# 3  https://www.scopus.com/inward/record.uri?eid=2...  46.0  2013
# 4  https://www.scopus.com/inward/record.uri?eid=2...  24.0  2012
#
#                                               AU_UN  \
# 0                          GEORGIA STATE UNIVERSITY
# 1  UNIVERSITY OF CALIFORNIA;INTEL RESEARCH BERKELEY
# 2                                               NaN
# 3   UNIVERSITY OF SHEFFIELD;UNIVERSITY OF SHEFFIELD
# 4                                UNIVERSITY OF HULL
#
#                                               AU1_UN  AU_UN_NR  \
# 0   NOTREPORTED;GEORGIA STATE UNIVERSITY;NOTREPORTED       NaN
# 1   NOTREPORTED;UNIVERSITY OF CALIFORNIA;NOTREPORTED       NaN
# 2                            NOTREPORTED;NOTREPORTED       NaN
# 3  NOTREPORTED;UNIVERSITY OF SHEFFIELDUNITED KING...       NaN
# 4  NOTREPORTED;UNIVERSITY OF HULLUNITED KINGDOM;N...       NaN
#
#                               SR_FULL                                  SR
# 0          VARSHNEY U, 2003, COMPUTER          VARSHNEY U, 2003, COMPUTER
# 1            SURANA S, 2008, COMPUTER            SURANA S, 2008, COMPUTER
# 2            HAZEN ME, 2008, COMPUTER            HAZEN ME, 2008, COMPUTER
# 3           SHARKEY N, 2013, COMPUTER           SHARKEY N, 2013, COMPUTER
# 4  BARRETT D, 2012, NURS OLDER PEOPLE  BARRETT D, 2012, NURS OLDER PEOPLE
#
# [5 rows x 32 columns]

# %%
df = df.rename(columns={"AU": "Author", "DE": "Department", "TI": "Title", "PY": "Publication Year", "C1": "Correspondence Address", "JI": "Journal", "VL": "Volume", "DB": "Source", "AB": "Abstract", "AU_UN": "Affiliation", "ID": "Keywords"})
def caps_title(x):
    if type(x) is str:
        return x.title()
    return x

df = df.applymap(caps_title)

# %%
df.head()
# Out:
#                                   Author  \
# 0                             Varshney U
# 1  Surana S;Patra R;Nedevschi S;Brewer E
# 2                               Hazen Me
# 3                    Sharkey N;Sharkey A
# 4                              Barrett D
#
#                                           Department  \
# 0                                                NaN
# 1  Information And Communication Technologies;  T...
# 2  Biotelemetric Data;  Body Network Sensors;  He...
# 3  Computer Science And Medicine;  Da Vinci Surgi...
# 4  Long-Term Conditions;  Remote Monitoring;  Tel...
#
#                                             Keywords  \
# 0  Mobile Devices;  Mobile Telemedicine; Data Pro...
# 1                                                NaN
# 2                                                NaN
# 3  Ethics;  Robodoc;  Robotic Surgery;  Surgical ...
# 4  Aged;  Ambulatory Monitoring;  Article;  Chron...
#
#                               Correspondence Address  \
# 0  Dept. Of Comp. Information Systems, Georgia St...
# 1  Electrical Engineering And Computer Sciences (...
# 2                                           Intellon
# 3  Departmento Of Ai And Robotics, University Of ...
# 4  Faculty Of Health And Social Care, University ...
#
#                                                   CR             Journal  \
# 0                                                NaN            Computer
# 1  Brewer, E., The Case For Technology In Develop...            Computer
# 2                                                NaN            Computer
# 3  Garcia, P., Trauma Pod: A Semi-Automated Teler...            Computer
# 4  Abraham, W., Adamson, P., Bourge, R., Wireless...  Nurs. Older People
#
#                                             Abstract         AR  coden  \
# 0  The Use Of The Wireless Communication Technolo...        NaN  Cptrb
# 1  A Novel Ict Project In Rural India Uses Long-D...        NaN  Cptrb
# 2  Service Providers Can Use Powerline Communicat...        NaN  Cptrb
# 3  Robotic Surgery Is A Relatively New Technology...  6374197.0  Cptrb
# 4  Long-Term Conditions Have A Negative Effect On...        NaN    NaN
#
#                                                   RP  ...  Source  \
# 0  Varshney, U.; Dept. Of Comp. Information Syste...  ...  Scopus
# 1  Surana, S.; Electrical Engineering And Compute...  ...  Scopus
# 2  Hazen, M.E.; Intellonemail: Mark.Hazen@Intello...  ...  Scopus
# 3  Sharkey, N.; Departmento Of Ai And Robotics, U...  ...  Scopus
# 4  Barrett, D.; Faculty Of Health And Social Care...  ...  Scopus
#
#                                                Title  \
# 0                               Pervasive Healthcare
# 1  Deploying A Rural Wireless Telemedicine System...
# 2  The Technology Behind Homeplug Av Powerline Co...
# 3     Robotic Surgery: On The Cutting Edge Of Ethics
# 4  The Role Of Telemonitoring In Caring For Older...
#
#                                                  url Volume Publication Year  \
# 0  Https://Www.Scopus.Com/Inward/Record.Uri?Eid=2...   36.0             2003
# 1  Https://Www.Scopus.Com/Inward/Record.Uri?Eid=2...   41.0             2008
# 2  Https://Www.Scopus.Com/Inward/Record.Uri?Eid=2...   41.0             2008
# 3  Https://Www.Scopus.Com/Inward/Record.Uri?Eid=2...   46.0             2013
# 4  Https://Www.Scopus.Com/Inward/Record.Uri?Eid=2...   24.0             2012
#
#                                         Affiliation  \
# 0                          Georgia State University
# 1  University Of California;Intel Research Berkeley
# 2                                               NaN
# 3   University Of Sheffield;University Of Sheffield
# 4                                University Of Hull
#
#                                               AU1_UN  AU_UN_NR  \
# 0   Notreported;Georgia State University;Notreported       NaN
# 1   Notreported;University Of California;Notreported       NaN
# 2                            Notreported;Notreported       NaN
# 3  Notreported;University Of Sheffieldunited King...       NaN
# 4  Notreported;University Of Hullunited Kingdom;N...       NaN
#
#                               SR_FULL                                  SR
# 0          Varshney U, 2003, Computer          Varshney U, 2003, Computer
# 1            Surana S, 2008, Computer            Surana S, 2008, Computer
# 2            Hazen Me, 2008, Computer            Hazen Me, 2008, Computer
# 3           Sharkey N, 2013, Computer           Sharkey N, 2013, Computer
# 4  Barrett D, 2012, Nurs Older People  Barrett D, 2012, Nurs Older People
#
# [5 rows x 32 columns]

# %%
df_ft = df[["Department", "Keywords", "Journal", "Abstract", "Title", "Publication Year", "Affiliation"]]
df_ft
# Out:
#                                             Department  \
# 0                                                  NaN
# 1    Information And Communication Technologies;  T...
# 2    Biotelemetric Data;  Body Network Sensors;  He...
# 3    Computer Science And Medicine;  Da Vinci Surgi...
# 4    Long-Term Conditions;  Remote Monitoring;  Tel...
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                               Keywords  \
# 0    Mobile Devices;  Mobile Telemedicine; Data Pro...
# 1                                                  NaN
# 2                                                  NaN
# 3    Ethics;  Robodoc;  Robotic Surgery;  Surgical ...
# 4    Aged;  Ambulatory Monitoring;  Article;  Chron...
# ..                                                 ...
# 138  Asynchronous Transfer Mode;  Carrier Communica...
# 139  Broadband Networks;  Computer Graphics;  Costs...
# 140  Computer Software;  Health Care;  Imaging Syst...
# 141  Artificial Intelligence;  Computer Application...
# 142  Color Image Processing;  Computer Workstations...
#
#                        Journal  \
# 0                     Computer
# 1                     Computer
# 2                     Computer
# 3                     Computer
# 4           Nurs. Older People
# ..                         ...
# 138                  Telephony
# 139           Advanced Imaging
# 140           Advanced Imaging
# 141  Comput Bull (London 1986)
# 142           Advanced Imaging
#
#                                               Abstract  \
# 0    The Use Of The Wireless Communication Technolo...
# 1    A Novel Ict Project In Rural India Uses Long-D...
# 2    Service Providers Can Use Powerline Communicat...
# 3    Robotic Surgery Is A Relatively New Technology...
# 4    Long-Term Conditions Have A Negative Effect On...
# ..                                                 ...
# 138  Starvision Multimedia Corp., An Affiliate Of N...
# 139  The Graphics Arts Industry Creates Enormous, I...
# 140  The Use Of Telemedicine As A Powerful Tool For...
# 141                                                NaN
# 142  The Digital Av Patient Knowledge System Is An ...
#
#                                                  Title  Publication Year  \
# 0                                 Pervasive Healthcare              2003
# 1    Deploying A Rural Wireless Telemedicine System...              2008
# 2    The Technology Behind Homeplug Av Powerline Co...              2008
# 3       Robotic Surgery: On The Cutting Edge Of Ethics              2013
# 4    The Role Of Telemonitoring In Caring For Older...              2012
# ..                                                 ...               ...
# 138                                  New Age Solutions              1996
# 139  Image Networking Now: Better Image Exchange Ac...              1996
# 140  Telemedicine Imaging Solutions For Remote Vide...              1996
# 141                       Health Computing In Scotland              1996
# 142  All Image Form Client. Server Database For Med...              1994
#
#                                           Affiliation
# 0                            Georgia State University
# 1    University Of California;Intel Research Berkeley
# 2                                                 NaN
# 3     University Of Sheffield;University Of Sheffield
# 4                                  University Of Hull
# ..                                                ...
# 138                                               NaN
# 139                                               NaN
# 140                                               NaN
# 141                                               NaN
# 142                                               NaN
#
# [143 rows x 7 columns]

# %%
df_ft["Publication Year"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
from itertools import chain

key_list = list(df_ft["Keywords"].dropna())
kw_list_split = list(chain(*[lst.split(";") for lst in key_list]))
counts_kws = pd.Series([item.strip() for item in kw_list_split]).value_counts()
counts_kws.head(50)
# Out:
# Telemedicine                   103
# Human                           34
# Article                         22
# Health Care                     20
# Information Technology          14
# United States                   14
# Humans                          14
# Internet                        13
# Telecommunication               10
# Note                            10
# Sensors                          9
# Chronic Disease                  9
# Patient Treatment                8
# Teleconferencing                 8
# Pharmacist                       8
# Telecommunication Services       8
# Medical Imaging                  8
# Patient Monitoring               8
# Real Time Systems                8
# Medicine                         7
# Information Processing           7
# Great Britain                    7
# Hospitals                        7
# Medical Applications             7
# Health Care Personnel            7
# Image Communication Systems      6
# Image Quality                    6
# Drug Industry                    6
# United Kingdom                   6
# Bandwidth                        6
# Economics                        6
# Health Care Cost                 6
# Biomedical Engineering           5
# Diagnosis                        5
# Computer Software                5
# Prescription                     5
# Health Care System               5
# Robotics                         5
# Textiles                         5
# Telehealth                       5
# Cameras                          5
# Health Care Delivery             5
# Drug Delivery System             5
# Monitoring                       5
# Video Conferencing               5
# Medical Computing                5
# Marketing                        5
# Organization And Management      5
# Aged                             4
# Database Systems                 4
# dtype: int64
