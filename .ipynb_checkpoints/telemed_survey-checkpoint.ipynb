# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np
sns.set() # Default seaborn styles

# %%
df = pd.read_csv('Use_of_Telemedicine_During_COVID-19.csv')

# %% [markdown]
# # Remap Indicator Values to Easier to Read Acronyms

# %%
indicator_remap = {'Provider offers telemedicine': 'TM', 'Provider offered telemedicine prior to pandemic': 'PTM', 'Scheduled one or more telemedicine appointments': 'STM' }
df['Indicator'] = df['Indicator'].map(indicator_remap)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Get %  of people answering "Yes" one of 3 Telemedicine Questions, Grouped by Age, Chronic Conditions, Etc.

# %%
all_yes = df.groupby(['Round','Group', 'Subgroup', 'Indicator']).nth(1).drop(['Sample Size', 'Suppression', 'Significant'], axis = 1)

# %% [markdown]
# ## Plot % of People with access to Telemedicine Before and After Pandemic

# %%
# Pivot so columns are % telehealth before, % scheduled telehealth, % telehealth after pandemic
indicator_by_sgroup = pd.pivot(all_yes.loc[1].reset_index(), index='Subgroup', columns='Indicator', values='Percent')
# Add a column calculating % change between telehealth now and telehealth before pandemic
indicator_by_sgroup['telemed before and after pandemic % change'] = (100 * (indicator_by_sgroup['TM'] - indicator_by_sgroup['PTM']) / indicator_by_sgroup['PTM']).round(2)

# %%
# Reorder columns
indicator_by_sgroup = indicator_by_sgroup.reindex(columns=['PTM', 'TM', "STM", 'telemed before and after pandemic % change'])
# Rename the 'Total' subgroup to be more clear
indicator_by_sgroup.rename(index={'Total': "Overall Average"}, inplace=True)

# Make the PairGrid
g = sns.PairGrid(indicator_by_sgroup.sort_values('telemed before and after pandemic % change', ascending=False).reset_index(),
                 x_vars=indicator_by_sgroup.columns[:-1], y_vars='Subgroup', height=15, aspect=.25)

# Draw a dot plot using the stripplot function
g.map(sns.stripplot, size=20, orient="h", jitter=False, palette="flare_r", linewidth=1, edgecolor="w")

# Use the same x axis limits on all columns and add better labels
g.set(xlim=(0, 60), xlabel="% Responding Yes", ylabel="")

# Use semantically meaningful titles for the columns
titles = ["Telemed Before Pandemic", "Telemed After Pandemic", "Scheduled Telemed Visit"]

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)

sns.despine(left=True, bottom=True)

g.savefig('yes_by_indicator.png')

# %%
# sns_data = indicator_by_sgroup.sort_values('telemed before and after pandemic % change', ascending=False).reset_index()
# sns.stripplot(sns_data, x=indicator_by_sgroup.columns[:-1], y="Subgroup")

# Make the PairGrid
g2 = sns.PairGrid(indicator_by_sgroup.sort_values('telemed before and after pandemic % change', ascending=False).reset_index(),
                 x_vars=indicator_by_sgroup.columns[:-1], y_vars='Subgroup', height=15, aspect=.25)

# Draw a dot plot using the stripplot function
g2.map(sns.stripplot, size=20, orient="h", jitter=False, linewidth=1, edgecolor="w")

# %% [markdown]
# # Table % of People with access to Telehealth Before and After Pandemic and % Ppl that schedule telehealth appointments

# %%
# Add a column calculating percentage of ppl with access to telemed actually scheduled 
indicator_by_sgroup['%scheduled of available telemed'] = (100 * indicator_by_sgroup['STM'] / indicator_by_sgroup['TM']).round(2)
indicator_by_sgroup.sort_values('telemed before and after pandemic % change', ascending=False)
# Out:
# Indicator                        PTM    TM   STM  \
# Subgroup
# Diagnosed diabetes              17.8  55.7  44.4
# Non-Metropolitan                11.6  35.7  22.6
# Diagnosed hypertension          15.1  45.6  32.9
# 65 years and over               15.3  45.9  32.0
# One or more chronic conditions  15.6  45.3  31.6
# White non-Hispanic              13.0  37.4  24.7
# 45-64 years                     13.9  39.8  26.9
# Female                          14.4  39.7  26.4
# High school graduate or less    13.2  35.0  23.1
# Overall Average                 14.1  36.6  24.2
# Some college                    13.8  35.4  24.2
# Bachelor's degree or above      15.5  39.5  25.5
# Metropolitan                    14.5  36.7  24.4
# Current asthma                  18.3  46.0  36.9
# Hispanic                        13.9  33.4  21.9
# Male                            13.9  33.4  22.0
# 18-44 years                     13.7  30.2  18.8
# Black non-Hispanic              18.0  38.5  27.4
# Other non-Hispanic              17.7  34.1  19.9
#
# Indicator                       telemed before and after pandemic % change  \
# Subgroup
# Diagnosed diabetes                                                  212.92
# Non-Metropolitan                                                    207.76
# Diagnosed hypertension                                              201.99
# 65 years and over                                                   200.00
# One or more chronic conditions                                      190.38
# White non-Hispanic                                                  187.69
# 45-64 years                                                         186.33
# Female                                                              175.69
# High school graduate or less                                        165.15
# Overall Average                                                     159.57
# Some college                                                        156.52
# Bachelor's degree or above                                          154.84
# Metropolitan                                                        153.10
# Current asthma                                                      151.37
# Hispanic                                                            140.29
# Male                                                                140.29
# 18-44 years                                                         120.44
# Black non-Hispanic                                                  113.89
# Other non-Hispanic                                                   92.66
#
# Indicator                       %scheduled of available telemed
# Subgroup
# Diagnosed diabetes                                        79.71
# Non-Metropolitan                                          63.31
# Diagnosed hypertension                                    72.15
# 65 years and over                                         69.72
# One or more chronic conditions                            69.76
# White non-Hispanic                                        66.04
# 45-64 years                                               67.59
# Female                                                    66.50
# High school graduate or less                              66.00
# Overall Average                                           66.12
# Some college                                              68.36
# Bachelor's degree or above                                64.56
# Metropolitan                                              66.49
# Current asthma                                            80.22
# Hispanic                                                  65.57
# Male                                                      65.87
# 18-44 years                                               62.25
# Black non-Hispanic                                        71.17
# Other non-Hispanic                                        58.36

# %%
survey_summary = indicator_by_sgroup.iloc[:, 0:3].rename({'PTM': '% Patients offered Telemedicine Before Covid', 'TM': '% Patients Offered Telemedicine During Covid', 'STM': '% Patients Scheduled Telemedicine Visit'}, axis=1)
survey_summary.to_csv('survey_summary.csv')

# %% [markdown]
# # Create weights

# %%
discarded_sgroups = ['Current asthma', 'Diagnosed diabetes', 'Diagnosed hypertension', 'Metropolitan', 'Non-Metropolitan', 'Overall Average']

# Remove pre-existing condition subgroups, metropolitan/non metro. subgroups, and the overall average
pre_weight_sgroups = indicator_by_sgroup.drop(discarded_sgroups, axis = 0).iloc[:, 3:]

# Calculate TM score metric
pre_weight_sgroups["TM_score"] = pre_weight_sgroups["telemed before and after pandemic % change"] / pre_weight_sgroups["%scheduled of available telemed"]

# %%
scaler = preprocessing.MinMaxScaler()

# Fit the scaler and rename columns, indices to original values
weights = pd.DataFrame(scaler.fit_transform(pre_weight_sgroups)).set_index(pre_weight_sgroups.index).rename({0: 'telemed before and after pandemic % change', 1: '%scheduled of available telemed', 2: 'TM_score'}, axis=1)
weights
# Out:
#                                 telemed before and after pandemic % change  \
# Subgroup
# 18-44 years                                                       0.258804
# 45-64 years                                                       0.872648
# 65 years and over                                                 1.000000
# Bachelor's degree or above                                        0.579281
# Black non-Hispanic                                                0.197783
# Female                                                            0.773523
# High school graduate or less                                      0.675331
# Hispanic                                                          0.443730
# Male                                                              0.443730
# One or more chronic conditions                                    0.910378
# Other non-Hispanic                                                0.000000
# Some college                                                      0.594932
# White non-Hispanic                                                0.885318
#
#                                 %scheduled of available telemed  TM_score
# Subgroup
# 18-44 years                                            0.303669  0.270944
# 45-64 years                                            0.720531  0.912679
# 65 years and over                                      0.886807  1.000000
# Bachelor's degree or above                             0.483997  0.632888
# Black non-Hispanic                                     1.000000  0.009776
# Female                                                 0.635441  0.823042
# High school graduate or less                           0.596409  0.713991
# Hispanic                                               0.562842  0.430807
# Male                                                   0.586261  0.423199
# One or more chronic conditions                         0.889930  0.891055
# Other non-Hispanic                                     0.000000  0.000000
# Some college                                           0.780640  0.547989
# White non-Hispanic                                     0.599532  0.979271

# %% [markdown]
# ## Put weights into a dictionary for easy mapping

# %%
# Keys are demographic subgroups. Values are a dictionary with the name of the score component and value is the weight itself
# {[subgroup] : {[score_component] : float, ...}, ...}
weights_dict = weights.to_dict(orient='index')
weights_dict
# Out:
# {'18-44 years': {'telemed before and after pandemic % change': 0.25880380100614864,
#   '%scheduled of available telemed': 0.3036690085870406,
#   'TM_score': 0.27094354428098644},
#  '45-64 years': {'telemed before and after pandemic % change': 0.8726476616359233,
#   '%scheduled of available telemed': 0.7205308352849338,
#   'TM_score': 0.9126787447453948},
#  '65 years and over': {'telemed before and after pandemic % change': 1.0,
#   '%scheduled of available telemed': 0.8868071818891483,
#   'TM_score': 1.0},
#  "Bachelor's degree or above": {'telemed before and after pandemic % change': 0.5792807900130428,
#   '%scheduled of available telemed': 0.48399687743950004,
#   'TM_score': 0.6328883056705845},
#  'Black non-Hispanic': {'telemed before and after pandemic % change': 0.1977827464132662,
#   '%scheduled of available telemed': 1.0,
#   'TM_score': 0.009775727656496924},
#  'Female': {'telemed before and after pandemic % change': 0.7735233836407676,
#   '%scheduled of available telemed': 0.6354410616705692,
#   'TM_score': 0.8230424576510549},
#  'High school graduate or less': {'telemed before and after pandemic % change': 0.675330724799702,
#   '%scheduled of available telemed': 0.5964090554254486,
#   'TM_score': 0.7139912543823574},
#  'Hispanic': {'telemed before and after pandemic % change': 0.4437302030929755,
#   '%scheduled of available telemed': 0.5628415300546434,
#   'TM_score': 0.4308066443713048},
#  'Male': {'telemed before and after pandemic % change': 0.4437302030929755,
#   '%scheduled of available telemed': 0.5862607338017174,
#   'TM_score': 0.423199097395915},
#  'One or more chronic conditions': {'telemed before and after pandemic % change': 0.9103782373765605,
#   '%scheduled of available telemed': 0.8899297423887589,
#   'TM_score': 0.8910549220334079},
#  'Other non-Hispanic': {'telemed before and after pandemic % change': 0.0,
#   '%scheduled of available telemed': 0.0,
#   'TM_score': 0.0},
#  'Some college': {'telemed before and after pandemic % change': 0.5949319918017515,
#   '%scheduled of available telemed': 0.7806401249024191,
#   'TM_score': 0.5479892365989913},
#  'White non-Hispanic': {'telemed before and after pandemic % change': 0.8853176821315447,
#   '%scheduled of available telemed': 0.5995316159250583,
#   'TM_score': 0.9792706677460354}}

# %% [markdown]
# # Score Census Tracks Using Weights

# %%
# Demographics % before scoring
tracks_raw = pd.read_csv('ready2weigh.csv')

# %%
# Apply TM_score weighting for each demographic
tracks = tracks_raw.iloc[:, :-5].apply(lambda series: series * weights_dict.get(series.name)['TM_score'])

# %%
# Add up the weighted demographic components of the LOT score
tracks['LOT_raw'] = tracks.iloc[:, :-5].sum(axis=1)

# %%
sns.distplot(tracks['LOT_raw'])
# Out:
# C:\Users\whou1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LOT_raw', ylabel='Density'>

# %%
# Segment data into 5 LOT bins
tracks['LOT'] = pd.cut(tracks['LOT_raw'], bins=5, labels=[1,2,3,4,5])

# %%
sns.histplot(tracks['LOT'])
# Out:
# <AxesSubplot:xlabel='LOT', ylabel='Count'>

# %%
# Add Geograph. back data to df
tracks['Lat'] = tracks_raw['latitude']
tracks['Long'] = tracks_raw['longitude']
tracks.iloc[:-1, -3:].to_csv('track_LOT.csv')

# %% [markdown]
# ## Get % Change of Telehealth Availability Before/After Pandemic Across Groups And rounds . Now Decided to stop looking at R1 v R2 Data -- didn't find much different between the two

# %% [markdown]
# ### Round 2 Responses (August 2020)

# %%
# # Deconstruct groupby df into component columns
# r2_reset = all_yes.loc[2].reset_index()
# # Add "Indicator" as a categorical column
# pivoted = r2_reset[r2_reset.Indicator == 'TM'].merge(right=r2_reset[r2_reset.Indicator == 'PTM'], on=['Group', 'Subgroup'], suffixes=('_tm', '_ptm'))
# # Add column currently offering telehealth - used to offer telehealth
# pivoted['tm-ptm diff'] = pivoted.Percent_tm - pivoted.Percent_ptm

# r2_differences_by_group = pivoted[['Group', 'Subgroup', 'tm-ptm diff']]
# r2_differences_by_group.sort_values(by='tm-ptm diff', ascending=False)
# Out:
#                    Group                        Subgroup  tm-ptm diff
# 4     Chronic conditions              Diagnosed diabetes         37.2
# 2              Age group               65 years and over         31.6
# 5     Chronic conditions          Diagnosed hypertension         31.1
# 6     Chronic conditions  One or more chronic conditions         29.1
# 3     Chronic conditions                  Current asthma         28.6
# 14                   Sex                          Female         26.5
# 7              Education      Bachelor's degree or above         26.5
# 1              Age group                     45-64 years         25.8
# 13  Race/Hispanic origin              White non-Hispanic         25.5
# 17          Urbanization                    Metropolitan         23.3
# 16                 Total                           Total         23.0
# 9              Education                    Some college         22.8
# 10  Race/Hispanic origin              Black non-Hispanic         21.9
# 18          Urbanization                Non-Metropolitan         20.9
# 8              Education    High school graduate or less         20.0
# 15                   Sex                            Male         19.1
# 12  Race/Hispanic origin              Other non-Hispanic         18.4
# 0              Age group                     18-44 years         17.2
# 11  Race/Hispanic origin                        Hispanic         16.1
